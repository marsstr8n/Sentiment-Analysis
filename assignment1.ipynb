# %% [markdown]
# # Assignment 1: Sentiment Analysis
#
# This assignment is a classification prediction of reviews collected from the three domains: imdb.com, amazon.com, yelp.com. The goal of the assignment is to develop an effective Bag of Words (BoW) feature engineering, and use a binary classifer to predict the sentiment (Positive or Negative) of held-out data.
#
# The assignment is divided into 4 sections:
# - Task 1: Data loading and Data preparation
# - Task 2: Feature representation
# - Task 3: Classification and evaluation
# - Task 4: Report
#
# Task 1-3 is displayed in this Jupyter notebook file, with Task 4 submitted in a .pdf file included with the submission. This Jupyter notebook however contains a Task 4 section which includes some code to supplement the report

# %% [markdown]
# ## Task 1: Data loading and Data preparation

# %%
# import libraries used in all tasks
import numpy as np
import pandas as pd
import string
import nltk

nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/marcustran/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Subtask 1.1: Load the datasets

# %%
# load the datasets. header=None so pd does not treat the first row as the header
x_columns = ['source', 'comment'] # x_test.csv and x_train.csv have two unnamed columns 
x_test = pd.read_csv("Dataset/x_test.csv", names=x_columns,header=None)
y_test = pd.read_csv("Dataset/y_test.csv",header=None)
x_train = pd.read_csv("Dataset/x_train.csv", names=x_columns,header=None)
y_train = pd.read_csv("Dataset/y_train.csv",header=None)


# change the data type to str for preprocessing
x_train['comment'] = x_train['comment'].astype(str)
x_test['comment'] = x_test['comment'].astype(str)

# drop the 'source' column as the source is not the subject of analysis
x_train.drop('source', axis=1, inplace=True)
x_test.drop('source', axis=1, inplace=True)

# check the y_train 0 (negative) and 1 (positive) distribution. Same with y_test
y_train.value_counts() # equal, 1: 1200, 0: 1200
y_test.value_counts() # equal, 1: 300, 0: 300

# make y_train 1D array for downstream ML
y_train_series = y_train.iloc[:,0]
y_test_series = y_test.iloc[:,0]

# %% [markdown]
# ### Subtask 1.2: Pre-processing the data
#
# The cleaning steps are:
# - Remove punctuations
# - Conversion to lower case
# - Remove stop words

# %%
# create a function to preprocess x_train and x_test: remove all punctuations, convert all to lower case, remove stop words

# create a function that removes punctuations
def remove_punctuation(text):
    """This function removes punctuations"""
    result = text
    for char in string.punctuation:
        result = result.replace(char, '')
    return result

# create a function to remove stop words
def remove_stopwords(text):
    """This function removes stop words"""
    tokens = word_tokenize(text)
    
    # specify the language
    english_stopwords = stopwords.words('english')
    tokens_no_stopwords = [t for t in tokens if t not in english_stopwords]
    text = " ".join(tokens_no_stopwords)
    
    return text
    
        
# a general preprocess function
def preprocess(text):
    """This function preprocesses the data:
    - Conversion to lower case
    - Remove punctuations
    - Remove stop words"""
    # lower case conversion
    text = text.lower()
    
    # remove punctuations
    text = remove_punctuation(text)
    
    # remove stop words
    text = remove_stopwords(text)
    
    return text


# apply preprocess function, and add result to a new column 'processed' - do it for both x_train and x_test
x_train['new_text'] = x_train['comment'].apply(preprocess)    

x_test['new_text'] = x_test['comment'].apply(preprocess)    
x_test
# Out:
#                                                comment  \
# 0    It only recognizes the Phone as its storage de...
# 1    Disappointing accessory from a good manufacturer.
# 2    The one big drawback of the MP3 player is that...
# 3    This particular model would not work with my M...
# 4    If the two were seperated by a mere 5+ ft I st...
# ..                                                 ...
# 595                Everything was fresh and delicious!
# 596                                             #NAME?
# 597                              Pretty awesome place.
# 598        The staff are great, the ambiance is great.
# 599            The patio seating was very comfortable.
#
#                                               new_text
# 0                      recognizes phone storage device
# 1            disappointing accessory good manufacturer
# 2    one big drawback mp3 player buttons phones fro...
# 3    particular model would work motorola q smartphone
# 4    two seperated mere 5 ft started notice excessi...
# ..                                                 ...
# 595                         everything fresh delicious
# 596                                               name
# 597                               pretty awesome place
# 598                         staff great ambiance great
# 599                          patio seating comfortable
#
# [600 rows x 2 columns]

# %% [markdown]
# ## Task 2: Feature representation
# - Since stop words have already been removed, no need to exclude common words
# - Keep all vocabularies, since it is a moderate size training set with 2400 documents
# - Unigrams only, since simplicity could be the most effective

# %%
vectorizer = CountVectorizer() # use CountVectorizer to count the word frequency
X_feature_train = vectorizer.fit_transform(x_train['new_text']) # transform x_train to the feature matrix

vectorizer.get_feature_names_out() # some also contains numbers


# ==== Optional: EDA on the 20 most frequent words ==== 
word_counts = np.array(X_feature_train.sum(axis=0)).flatten() # get total word frequencies across all docs

# map word to count
vocab = vectorizer.get_feature_names_out()
word_freq = pd.DataFrame({'word': vocab, 'count': word_counts})

# sort and show top 20 most frequent words:
top_words = word_freq.sort_values(by='count', ascending=False).head(20)
print(top_words)

# transform preprocessed x_test using vectorizer too - using the same vectorizer
X_feature_test = vectorizer.transform(x_test['new_text'])

X_feature_train
# printing this shows: 2400 - number of rows in x_train['new_text'] (documents)
# 4564: number of unique words in all docs (vocabulary size)
# 14608: number of non-zero word count
# Out:
#          word  count
# 1771     good    183
# 1793    great    162
# 2605    movie    141
# 2925    phone    137
# 1546     film    122
# 2753      one    112
# 2950    place    100
# 1622     food     99
# 2319     like     95
# 3521  service     85
# 4048     time     84
# 3199   really     79
# 338       bad     79
# 4517    would     75
# 4427     well     71
# 1203     dont     65
# 1396     even     64
# 1401     ever     63
# 424      best     63
# 332      back     62
# <2400x4564 sparse matrix of type '<class 'numpy.int64'>'
# 	with 14608 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Task 3: Classification and Evaluation
# - Multinomial Naive Bayes Classifer is chosen for document classification problems - use the frequency of words as the predictor
#
# Justifications:
# - works well with high-dimensional text data
# - fits with BoW - as it uses the word frequency, which is kept in CountVectorizer()
# - simple, fast yet effective

# %% [markdown]
# ### Subtask 3.1: Splitting the training data into test set and training set
# - Since the comment sentiment distribution are closely equal, I don't have to use stratified sampling
#
# - Split the data in several ways to ensure that the result is robust: 80/20, then 70/30, lastly 90/10 for train/test ratio - have random_state = 42 for reproducibility

# %%
# split the training set into 3 different train/validate ratios. Denote X and Y to differentiate from x_train and y_train
# 80/20
X_train_1, X_val_1, Y_train_1, Y_val_1 = train_test_split(X_feature_train, y_train_series, test_size=0.2, random_state=42)
# 70/30
X_train_2, X_val_2, Y_train_2, Y_val_2 = train_test_split(X_feature_train, y_train_series, test_size=0.3, random_state=42)
# 90/10
X_train_3, X_val_3, Y_train_3, Y_val_3 = train_test_split(X_feature_train, y_train_series, test_size=0.1, random_state=42)

# %% [markdown]
# ### Subtask 3.2:
# - Model Setup
# - Cross-Validation with Hyperparameter Tuning: Use GridSearchCV with 5-fold. F1-score is the success metric
# - Apply the best parameter, and predict the validation sets for all three split sets
# - Fit the classifer to the entire training data, and evaluate its performance on the test set

# %%
nb_classifier = MultinomialNB() # set up the classifer

# setting up param_grid
param_grid = {'alpha': [0.1, 0.5, 1, 2, 5, 10]}

# setting up GridSearchCV
grid_search = GridSearchCV(
    estimator=nb_classifier,
    param_grid=param_grid,
    scoring='f1',
    cv=5, # set 5 folds
    verbose=1
)

# 80/20 split
grid_search.fit(X_train_1, Y_train_1)
best_80_20 = grid_search.best_params_, grid_search.best_score_
print("80/20 split", best_80_20)

# 70/30 split
grid_search.fit(X_train_2, Y_train_2)
best_70_30 = grid_search.best_params_, grid_search.best_score_
print("70/30 split", best_70_30)

# 90/10 split
grid_search.fit(X_train_3, Y_train_3)
best_90_10 = grid_search.best_params_, grid_search.best_score_
print("90/10 split", best_90_10)

# alpha 0.5 is the most suitable, as it was selected 2 out of 3, and gives the best f1 score


# apply alpha=0.5 onto MultinomialNB, retrain X_train, and apply to predict X_val sets
nb_classifier = MultinomialNB(alpha=0.5) # set up the classifer
nb_classifier.fit(X_train_1, Y_train_1)

# predict on validation data
Y_pred_1 = nb_classifier.predict(X_val_1)

# Evaluate - comparing the predicted vs the actual values
print("\n80/20 split")
print(classification_report(Y_val_1, Y_pred_1))
print(confusion_matrix(Y_val_1, Y_pred_1))

# Repeat the steps for 70/30 and 90/10 splits
# 70/30
nb_classifier.fit(X_train_2, Y_train_2)

# predict on validation data
Y_pred_2 = nb_classifier.predict(X_val_2)

# Evaluate - comparing the predicted vs the actual values
print("\n70/30 split")
print(classification_report(Y_val_2, Y_pred_2))
print(confusion_matrix(Y_val_2, Y_pred_2))

# 90/10
nb_classifier.fit(X_train_3, Y_train_3)

# predict on validation data
Y_pred_3 = nb_classifier.predict(X_val_3)

# Evaluate - comparing the predicted vs the actual values
print("\n90/10 split")
print(classification_report(Y_val_3, Y_pred_3))
print(confusion_matrix(Y_val_3, Y_pred_3))


# results are consistent, with 80/20 split giving the best results
# fit the classifier to the entire training data

nb_classifier.fit(X_feature_train, y_train_series)
y_pred = nb_classifier.predict(X_feature_test)

# Evaluate - comparing the predicted vs the actual values
print("\nTest set prediction")
print(classification_report(y_test_series, y_pred))
print(confusion_matrix(y_test_series, y_pred))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 80/20 split ({'alpha': 0.5}, 0.7925993213506387)
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 70/30 split ({'alpha': 1}, 0.7829276439391594)
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 90/10 split ({'alpha': 0.5}, 0.8023144808719864)
#
# 80/20 split
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       237
#            1       0.82      0.84      0.83       243
#
#     accuracy                           0.83       480
#    macro avg       0.83      0.83      0.83       480
# weighted avg       0.83      0.83      0.83       480
#
# [[192  45]
#  [ 38 205]]
#
# 70/30 split
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       348
#            1       0.80      0.84      0.82       372
#
#     accuracy                           0.81       720
#    macro avg       0.81      0.81      0.81       720
# weighted avg       0.81      0.81      0.81       720
#
# [[272  76]
#  [ 59 313]]
#
# 90/10 split
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       117
#            1       0.82      0.80      0.81       123
#
#     accuracy                           0.80       240
#    macro avg       0.80      0.80      0.80       240
# weighted avg       0.80      0.80      0.80       240
#
# [[95 22]
#  [25 98]]
#
# Test set prediction
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       300
#            1       0.81      0.80      0.81       300
#
#     accuracy                           0.81       600
#    macro avg       0.81      0.81      0.81       600
# weighted avg       0.81      0.81      0.81       600
#
# [[244  56]
#  [ 59 241]]

# %% [markdown]
# ## Task 4: Report
# This section contains some code that is used to illustrate topics written in the report

# %%
# check for the false positives and negative in 80/20 set evaluation
text_train = x_train['new_text'].tolist() 
comment_train = x_train['comment'].tolist() 

for i, (true, pred) in enumerate(zip(Y_val_1, Y_pred_1)):
    if true != pred:
        print(f"Original Text: {comment_train[i]}")
        print(f"Preprocessed Text: {text_train[i]}")
        print(f"True: {true}, Pred: {pred}\n")
# Out:
# Original Text: The only thing that disappoint me is the infra red port (irda).
# Preprocessed Text: thing disappoint infra red port irda
# True: 0, Pred: 1
#
# Original Text: Doesn't hold charge.
# Preprocessed Text: doesnt hold charge
# True: 1, Pred: 0
#
# Original Text: Can't store anything but phone numbers to SIM.
# Preprocessed Text: cant store anything phone numbers sim
# True: 0, Pred: 1
#
# Original Text: Very disappointing.
# Preprocessed Text: disappointing
# True: 1, Pred: 0
#
# Original Text: I would not recommend this item to anyone.
# Preprocessed Text: would recommend item anyone
# True: 1, Pred: 0
#
# Original Text: Just does not work.
# Preprocessed Text: work
# True: 1, Pred: 0
#
# Original Text: In my house I was getting dropped coverage upstairs and no coverage in my basement.
# Preprocessed Text: house getting dropped coverage upstairs coverage basement
# True: 1, Pred: 0
#
# Original Text: [...] down the drain because of a weak snap!
# Preprocessed Text: drain weak snap
# True: 1, Pred: 0
#
# Original Text: Defective crap.
# Preprocessed Text: defective crap
# True: 0, Pred: 1
#
# Original Text: I really wanted the Plantronics 510 to be the right one, but it has too many issues for me.The good
# Preprocessed Text: really wanted plantronics 510 right one many issues methe good
# True: 0, Pred: 1
#
# Original Text: Performed awful -- muffled, tinny incoming sound and severe echo for those on the other end of the call.
# Preprocessed Text: performed awful muffled tinny incoming sound severe echo end call
# True: 1, Pred: 0
#
# Original Text: It dit not work most of the time with my Nokia 5320.
# Preprocessed Text: dit work time nokia 5320
# True: 1, Pred: 0
#
# Original Text: I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.
# Preprocessed Text: ive bluetoooth headset time still comfortable way fits ear
# True: 0, Pred: 1
#
# Original Text: dont buy it.
# Preprocessed Text: dont buy
# True: 0, Pred: 1
#
# Original Text: Problem is that the ear loops are made of weak material and break easily.
# Preprocessed Text: problem ear loops made weak material break easily
# True: 0, Pred: 1
#
# Original Text: I put the latest OS on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.
# Preprocessed Text: put latest os v115g likes slow crawl lock every
# True: 1, Pred: 0
#
# Original Text: It was a waste of my money.
# Preprocessed Text: waste money
# True: 1, Pred: 0
#
# Original Text: Worst software ever used.... If I could give this zero stars I would.
# Preprocessed Text: worst software ever used could give zero stars would
# True: 0, Pred: 1
#
# Original Text: Lousy product.
# Preprocessed Text: lousy product
# True: 1, Pred: 0
#
# Original Text: Were JERKS on the phone.
# Preprocessed Text: jerks phone
# True: 1, Pred: 0
#
# Original Text: All in all, I'd expected a better consumer experience from Motorola.
# Preprocessed Text: id expected better consumer experience motorola
# True: 0, Pred: 1
#
# Original Text: Doesn't work at all.. I bougth it for my L7c and its not working.
# Preprocessed Text: doesnt work bougth l7c working
# True: 1, Pred: 0
#
# Original Text: very disappointed.
# Preprocessed Text: disappointed
# True: 0, Pred: 1
#
# Original Text: Case was more or less an extra that I originally put on but later discarded because it scratched my ear.
# Preprocessed Text: case less extra originally put later discarded scratched ear
# True: 0, Pred: 1
#
# Original Text: Bad Purchase.
# Preprocessed Text: bad purchase
# True: 1, Pred: 0
#
# Original Text: I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway.
# Preprocessed Text: bother contacting company dollar product learned lesson bought form online anyway
# True: 0, Pred: 1
#
# Original Text: Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3.
# Preprocessed Text: reaching bottom row uncomfortable send end keys expect be3
# True: 0, Pred: 1
#
# Original Text: The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently.
# Preprocessed Text: calls drop phone comes screen goes black worst stops ringing intermittently
# True: 0, Pred: 1
#
# Original Text: I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.
# Preprocessed Text: kept catching cable seat pull phone turn
# True: 1, Pred: 0
#
# Original Text: Piece of trash.
# Preprocessed Text: piece trash
# True: 0, Pred: 1
#
# Original Text: The camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution.
# Preprocessed Text: camera although rated impressive 13 megapixels renders images fall well expectations relatively high resolution
# True: 1, Pred: 0
#
# Original Text: Item Does Not Match Picture.
# Preprocessed Text: item match picture
# True: 1, Pred: 0
#
# Original Text: I am not impressed with this and i would not recommend this item to anyone.
# Preprocessed Text: impressed would recommend item anyone
# True: 1, Pred: 0
#
# Original Text: It's A PIECE OF CRAP!
# Preprocessed Text: piece crap
# True: 1, Pred: 0
#
# Original Text: Talk about USELESS customer service.
# Preprocessed Text: talk useless customer service
# True: 0, Pred: 1
#
# Original Text: It's uncomfortable and the sound quality is quite poor compared with the phone (Razr) or with my previous wired headset (that plugged into an LG).
# Preprocessed Text: uncomfortable sound quality quite poor compared phone razr previous wired headset plugged lg
# True: 1, Pred: 0
#
# Original Text: Echo Problem....Very unsatisfactory
# Preprocessed Text: echo problemvery unsatisfactory
# True: 0, Pred: 1
#
# Original Text: The loudspeaker option is great, the bumpers with the lights is very ... appealing.
# Preprocessed Text: loudspeaker option great bumpers lights appealing
# True: 0, Pred: 1
#
# Original Text: Do not make the same mistake as me.
# Preprocessed Text: make mistake
# True: 1, Pred: 0
#
# Original Text: Not worth it.
# Preprocessed Text: worth
# True: 0, Pred: 1
#
# Original Text: VERY DISAPPOINTED.
# Preprocessed Text: disappointed
# True: 1, Pred: 0
#
# Original Text: The pleather case doesn't fit.
# Preprocessed Text: pleather case doesnt fit
# True: 1, Pred: 0
#
# Original Text: I does not maintain a connection with the computer while it is on my lap.
# Preprocessed Text: maintain connection computer lap
# True: 0, Pred: 1
#
# Original Text: Chinese Forgeries Abound!.
# Preprocessed Text: chinese forgeries abound
# True: 0, Pred: 1
#
# Original Text: It lasts less than 3o minutes, if I actually try to use the phone.My wife has the same phone with the same problem.
# Preprocessed Text: lasts less 3o minutes actually try use phonemy wife phone problem
# True: 0, Pred: 1
#
# Original Text: Verizon tech support walked my through a few procedures, none of which worked and I ended up having to do a hard re-set, wiping out all my data.
# Preprocessed Text: verizon tech support walked procedures none worked ended hard reset wiping data
# True: 1, Pred: 0
#
# Original Text: They refuse to refund or replace.
# Preprocessed Text: refuse refund replace
# True: 0, Pred: 1
#
# Original Text: The worst phone I've ever had.... Only had it for a few months.
# Preprocessed Text: worst phone ive ever months
# True: 1, Pred: 0
#
# Original Text: I wouldn't recommend buying this product.
# Preprocessed Text: wouldnt recommend buying product
# True: 0, Pred: 1
#
# Original Text: Bad Reception.
# Preprocessed Text: bad reception
# True: 0, Pred: 1
#
# Original Text: When I placed my treo into the case, not only was it NOT snug, but there was A LOT of extra room on the sides.
# Preprocessed Text: placed treo case snug lot extra room sides
# True: 0, Pred: 1
#
# Original Text: Painful on the ear.
# Preprocessed Text: painful ear
# True: 0, Pred: 1
#
# Original Text: Voice Quality, Signal Strength, Dropped Calls.
# Preprocessed Text: voice quality signal strength dropped calls
# True: 0, Pred: 1
#
# Original Text: it did not work in my cell phone plug i am very up set with the charger!.
# Preprocessed Text: work cell phone plug set charger
# True: 1, Pred: 0
#
# Original Text: I had to purchase a different case.
# Preprocessed Text: purchase different case
# True: 0, Pred: 1
#
# Original Text: However, BT headsets are currently not good for real time games like first-person shooters since the audio delay messes me up.
# Preprocessed Text: however bt headsets currently good real time games like firstperson shooters since audio delay messes
# True: 0, Pred: 1
#
# Original Text: It looses connection to the phone even when it is within a couple feet between the two.
# Preprocessed Text: looses connection phone even within couple feet two
# True: 1, Pred: 0
#
# Original Text: Also, the phone doesn't seem to accept anything except CBR mp3s, preferably ripped by Windows Media Player.
# Preprocessed Text: also phone doesnt seem accept anything except cbr mp3s preferably ripped windows media player
# True: 0, Pred: 1
#
# Original Text: Same problem as others have mentioned.
# Preprocessed Text: problem others mentioned
# True: 0, Pred: 1
#
# Original Text: My only complaint is the standard sound volume is a little low even when turned up to 5(of 5)
# Preprocessed Text: complaint standard sound volume little low even turned 5of 5
# True: 0, Pred: 1
#
# Original Text: Customer service was terrible.
# Preprocessed Text: customer service terrible
# True: 0, Pred: 1
#
# Original Text: I have had problems wit hit dropping signal and more.
# Preprocessed Text: problems wit hit dropping signal
# True: 1, Pred: 0
#
# Original Text: Mic Doesn't work.
# Preprocessed Text: mic doesnt work
# True: 1, Pred: 0
#
# Original Text: It is practically useless and did not add any kind of boost to my reception after I bought it.
# Preprocessed Text: practically useless add kind boost reception bought
# True: 1, Pred: 0
#
# Original Text: The buttons for on and off are bad.
# Preprocessed Text: buttons bad
# True: 0, Pred: 1
#
# Original Text: The plug did not work very well.
# Preprocessed Text: plug work well
# True: 0, Pred: 1
#
# Original Text: I was very excited to get this headset because I thought it was really cute.
# Preprocessed Text: excited get headset thought really cute
# True: 0, Pred: 1
#
# Original Text: Razr Battery - Good buy.
# Preprocessed Text: razr battery good buy
# True: 1, Pred: 0
#
# Original Text: Worth every penny.
# Preprocessed Text: worth every penny
# True: 1, Pred: 0
#
# Original Text: For the price this was a great deal.
# Preprocessed Text: price great deal
# True: 0, Pred: 1
#
# Original Text: Overall, I am psyched to have a phone which has all my appointments and contacts in and gets great reception.
# Preprocessed Text: overall psyched phone appointments contacts gets great reception
# True: 0, Pred: 1
#
# Original Text: Highly recommend for any one who has a blue tooth phone.
# Preprocessed Text: highly recommend one blue tooth phone
# True: 0, Pred: 1
#
# Original Text: It fits my ear well and is comfortable on.
# Preprocessed Text: fits ear well comfortable
# True: 1, Pred: 0
#
# Original Text: The bose noise cancelling is amazing, which is very important for a NYC commuter.
# Preprocessed Text: bose noise cancelling amazing important nyc commuter
# True: 0, Pred: 1
#
# Original Text: The reception through this headset is excellent.
# Preprocessed Text: reception headset excellent
# True: 0, Pred: 1
#
# Original Text: Reversible plug works great.
# Preprocessed Text: reversible plug works great
# True: 1, Pred: 0
#
# Original Text: Phone now holds charge like it did when it was new.
# Preprocessed Text: phone holds charge like new
# True: 1, Pred: 0
#
# Original Text: Overall, I would recommend this phone over the new Walkman.
# Preprocessed Text: overall would recommend phone new walkman
# True: 0, Pred: 1
#
# Original Text: Very good stuff for the price.
# Preprocessed Text: good stuff price
# True: 1, Pred: 0
#
# Original Text: After charging overnight, these batteries work great.
# Preprocessed Text: charging overnight batteries work great
# True: 0, Pred: 1
#
# Original Text: I had to go to a store and bought a new NOKIA phone which is working great.
# Preprocessed Text: go store bought new nokia phone working great
# True: 1, Pred: 0
#
# Original Text: #1 It Works - #2 It is Comfortable.
# Preprocessed Text: 1 works 2 comfortable
# True: 0, Pred: 1
#
# Original Text: The phone can also take great pictures and even video clips.
# Preprocessed Text: phone also take great pictures even video clips
# True: 1, Pred: 0

# %%
# check accurate predictions
count = 0
for i, (true, pred) in enumerate(zip(Y_val_1, Y_pred_1)):
    if true == pred:
        print(f"Original Text: {comment_train[i]}")
        print(f"Preprocessed Text: {text_train[i]}")
        print(f"True: {true}, Pred: {pred}\n")
        count += 1
        if count == 30:
            break
# Out:
# Original Text: Oh and I forgot to also mention the weird color effect it has on your phone.
# Preprocessed Text: oh forgot also mention weird color effect phone
# True: 1, Pred: 1
#
# Original Text: THAT one didn't work either.
# Preprocessed Text: one didnt work either
# True: 0, Pred: 0
#
# Original Text: Waste of 13 bucks.
# Preprocessed Text: waste 13 bucks
# True: 0, Pred: 0
#
# Original Text: Product is useless, since it does not have enough charging current to charge the 2 cellphones I was planning to use it with.
# Preprocessed Text: product useless since enough charging current charge 2 cellphones planning use
# True: 0, Pred: 0
#
# Original Text: None of the three sizes they sent with the headset would stay in my ears.
# Preprocessed Text: none three sizes sent headset would stay ears
# True: 1, Pred: 1
#
# Original Text: Worst customer service.
# Preprocessed Text: worst customer service
# True: 0, Pred: 0
#
# Original Text: The Ngage is still lacking in earbuds.
# Preprocessed Text: ngage still lacking earbuds
# True: 1, Pred: 1
#
# Original Text: It always cuts out and makes a beep beep beep sound then says signal failed.
# Preprocessed Text: always cuts makes beep beep beep sound says signal failed
# True: 0, Pred: 0
#
# Original Text: the only VERY DISAPPOINTING thing was there was NO SPEAKERPHONE!!!!
# Preprocessed Text: disappointing thing speakerphone
# True: 1, Pred: 1
#
# Original Text: Very disappointed in AccessoryOne.
# Preprocessed Text: disappointed accessoryone
# True: 0, Pred: 0
#
# Original Text: Basically the service was very bad.
# Preprocessed Text: basically service bad
# True: 0, Pred: 0
#
# Original Text: Bad Choice.
# Preprocessed Text: bad choice
# True: 0, Pred: 0
#
# Original Text: horrible, had to switch 3 times.
# Preprocessed Text: horrible switch 3 times
# True: 1, Pred: 1
#
# Original Text: It feels poorly constructed, the menus are difficult to navigate, and the buttons are so recessed that it is difficult to push them.
# Preprocessed Text: feels poorly constructed menus difficult navigate buttons recessed difficult push
# True: 0, Pred: 0
#
# Original Text: Don't make the same mistake I did.
# Preprocessed Text: dont make mistake
# True: 0, Pred: 0
#
# Original Text: Muddy, low quality sound, and the casing around the wire's insert was poorly super glued and slid off.
# Preprocessed Text: muddy low quality sound casing around wires insert poorly super glued slid
# True: 0, Pred: 0
#
# Original Text: I advise EVERYONE DO NOT BE FOOLED!
# Preprocessed Text: advise everyone fooled
# True: 0, Pred: 0
#
# Original Text: What a waste of time!
# Preprocessed Text: waste time
# True: 1, Pred: 1
#
# Original Text: I'm very disappointed with my decision.
# Preprocessed Text: im disappointed decision
# True: 0, Pred: 0
#
# Original Text: I also didn't like the "on" button, it felt like it would crack with use.
# Preprocessed Text: also didnt like button felt like would crack use
# True: 1, Pred: 1
#
# Original Text: I bought these hoping I could make my Bluetooth headset fit better but these things made it impossible to wear.
# Preprocessed Text: bought hoping could make bluetooth headset fit better things made impossible wear
# True: 0, Pred: 0
#
# Original Text: We have tried 2 units and they both failed within 2 months.. Pros
# Preprocessed Text: tried 2 units failed within 2 months pros
# True: 1, Pred: 1
#
# Original Text: Also difficult to put on.I'd recommend avoiding this product.
# Preprocessed Text: also difficult put onid recommend avoiding product
# True: 1, Pred: 1
#
# Original Text: $50 Down the drain.
# Preprocessed Text: 50 drain
# True: 1, Pred: 1
#
# Original Text: Absolutel junk.
# Preprocessed Text: absolutel junk
# True: 1, Pred: 1
#
# Original Text: Big Disappointment with calendar sync.
# Preprocessed Text: big disappointment calendar sync
# True: 0, Pred: 0
#
# Original Text: Not impressed.
# Preprocessed Text: impressed
# True: 0, Pred: 0
#
# Original Text: I even fully charged it before I went to bed and turned off blue tooth and wi-fi and noticed that it only had 20 % left in the morning.
# Preprocessed Text: even fully charged went bed turned blue tooth wifi noticed 20 left morning
# True: 0, Pred: 0
#
# Original Text: Plus, I seriously do not believe it is worth its steep price point.
# Preprocessed Text: plus seriously believe worth steep price point
# True: 0, Pred: 0
#
# Original Text: The phone takes FOREVER to charge like 2 to 5 hours literally.
# Preprocessed Text: phone takes forever charge like 2 5 hours literally
# True: 0, Pred: 0

# %%
# check for the false positives and negative in test set
text_test = x_test['new_text'].tolist() 
comment_test = x_test['comment'].tolist() 

for i, (true, pred) in enumerate(zip(y_test_series, y_pred)):
    if true != pred:
        print(f"Original Text: {comment_test[i]}")
        print(f"Preprocessed Text: {text_test[i]}")
        print(f"True: {true}, Pred: {pred}\n")
# Out:
# Original Text: It only recognizes the Phone as its storage device.
# Preprocessed Text: recognizes phone storage device
# True: 0, Pred: 1
#
# Original Text: I purchased this and within 2 days it was no longer working!!!!!!!!!
# Preprocessed Text: purchased within 2 days longer working
# True: 0, Pred: 1
#
# Original Text: AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.
# Preprocessed Text: arguing verizon regarding dropped calls returned phones two days
# True: 0, Pred: 1
#
# Original Text: My experience was terrible..... This was my fourth bluetooth headset, and while it was much more comfortable than my last Jabra (which I HATED!!!
# Preprocessed Text: experience terrible fourth bluetooth headset much comfortable last jabra hated
# True: 0, Pred: 1
#
# Original Text: When it opens, the battery connection is broken and the device is turned off.
# Preprocessed Text: opens battery connection broken device turned
# True: 0, Pred: 1
#
# Original Text: Not as good as I had hoped.
# Preprocessed Text: good hoped
# True: 0, Pred: 1
#
# Original Text: Doesn't do the job.
# Preprocessed Text: doesnt job
# True: 0, Pred: 1
#
# Original Text: Does not fit.
# Preprocessed Text: fit
# True: 0, Pred: 1
#
# Original Text: Not good when wearing a hat or sunglasses.
# Preprocessed Text: good wearing hat sunglasses
# True: 0, Pred: 1
#
# Original Text: The camera on the phone may be used as a dustpan when indoors... I'd rather be using a disposable then this.
# Preprocessed Text: camera phone may used dustpan indoors id rather using disposable
# True: 0, Pred: 1
#
# Original Text: This item worked great, but it broke after 6 months of use.
# Preprocessed Text: item worked great broke 6 months use
# True: 0, Pred: 1
#
# Original Text: Its not user friendly.
# Preprocessed Text: user friendly
# True: 0, Pred: 1
#
# Original Text: It defeats the purpose of a bluetooth headset.
# Preprocessed Text: defeats purpose bluetooth headset
# True: 0, Pred: 1
#
# Original Text: Not a good bargain.
# Preprocessed Text: good bargain
# True: 0, Pred: 1
#
# Original Text: I have bought this Nokia cell phone a few weeks ago and it was a nightmare.
# Preprocessed Text: bought nokia cell phone weeks ago nightmare
# True: 0, Pred: 1
#
# Original Text: Items stated as included from the description ARE NOT INCLUDED.
# Preprocessed Text: items stated included description included
# True: 0, Pred: 1
#
# Original Text: DO NOT PURCHASE THIS PHONE.
# Preprocessed Text: purchase phone
# True: 0, Pred: 1
#
# Original Text: Was not happy.
# Preprocessed Text: happy
# True: 0, Pred: 1
#
# Original Text: Cheap but hey it works.. Was pleasantly suprised given the low cost of this item.
# Preprocessed Text: cheap hey works pleasantly suprised given low cost item
# True: 1, Pred: 0
#
# Original Text: The delivery was on time.
# Preprocessed Text: delivery time
# True: 1, Pred: 0
#
# Original Text: The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity.
# Preprocessed Text: eargels channel sound directly ear seem increase sound volume clarity
# True: 1, Pred: 0
#
# Original Text: He was very impressed when going from the original battery to the extended battery.
# Preprocessed Text: impressed going original battery extended battery
# True: 1, Pred: 0
#
# Original Text: The design is very good.4.
# Preprocessed Text: design good4
# True: 1, Pred: 0
#
# Original Text: It plays louder than any other speaker of this size; the price is so low that most would think the quality is lacking, however, it's not.
# Preprocessed Text: plays louder speaker size price low would think quality lacking however
# True: 1, Pred: 0
#
# Original Text: A good quality bargain.. I bought this after I bought a cheapy from Big Lots that sounded awful and people on the other end couldn't hear me.
# Preprocessed Text: good quality bargain bought bought cheapy big lots sounded awful people end couldnt hear
# True: 1, Pred: 0
#
# Original Text: I've had no trouble accessing the Internet, downloading ringtones or performing any of the functions.
# Preprocessed Text: ive trouble accessing internet downloading ringtones performing functions
# True: 1, Pred: 0
#
# Original Text: Just reading on the specs alone makes you say WOW.
# Preprocessed Text: reading specs alone makes say wow
# True: 1, Pred: 0
#
# Original Text: I have read other's reviews here but I haven't had any problem with it.
# Preprocessed Text: read others reviews havent problem
# True: 1, Pred: 0
#
# Original Text: This fixes all the problems.
# Preprocessed Text: fixes problems
# True: 1, Pred: 0
#
# Original Text: But despite these few flaws, this case is of exceptional quality and well worth the additional costs of owning an official OEM product.
# Preprocessed Text: despite flaws case exceptional quality well worth additional costs owning official oem product
# True: 1, Pred: 0
#
# Original Text: im surprised this is a good quality car charger and there's not much reviews about it.
# Preprocessed Text: im surprised good quality car charger theres much reviews
# True: 1, Pred: 0
#
# Original Text: Yes it's shiny on front side - and I love it!
# Preprocessed Text: yes shiny front side love
# True: 1, Pred: 0
#
# Original Text: I have always used corded headsets and the freedom from the wireless is very helpful.
# Preprocessed Text: always used corded headsets freedom wireless helpful
# True: 1, Pred: 0
#
# Original Text: The result is a film that just don't look right.
# Preprocessed Text: result film dont look right
# True: 0, Pred: 1
#
# Original Text: Maybe there would be a reasonable explanation for this atrocity.
# Preprocessed Text: maybe would reasonable explanation atrocity
# True: 0, Pred: 1
#
# Original Text: The film is way too long.
# Preprocessed Text: film way long
# True: 0, Pred: 1
#
# Original Text: Not even good for camp value!
# Preprocessed Text: even good camp value
# True: 0, Pred: 1
#
# Original Text: This short film certainly pulls no punches.
# Preprocessed Text: short film certainly pulls punches
# True: 0, Pred: 1
#
# Original Text: I guess it was supposed to be clever twist, then shed some light on the situation, but it was just stupid.
# Preprocessed Text: guess supposed clever twist shed light situation stupid
# True: 0, Pred: 1
#
# Original Text: This was reflected not only in the cast, but also in the below-par script, which borrowed much from the earlier classic.
# Preprocessed Text: reflected cast also belowpar script borrowed much earlier classic
# True: 0, Pred: 1
#
# Original Text: The only consistent thread holding the series together were the amazing performances of Leni Parker and Anita LaSelva as the two Taelons in quiet idealogical conflict.
# Preprocessed Text: consistent thread holding series together amazing performances leni parker anita laselva two taelons quiet idealogical conflict
# True: 0, Pred: 1
#
# Original Text: The directing and the cinematography aren't quite as good.
# Preprocessed Text: directing cinematography arent quite good
# True: 0, Pred: 1
#
# Original Text: I saw "Mirrormask" last night and it was an unsatisfactory experience.
# Preprocessed Text: saw mirrormask last night unsatisfactory experience
# True: 0, Pred: 1
#
# Original Text: but the movie makes a lot of serious mistakes.
# Preprocessed Text: movie makes lot serious mistakes
# True: 0, Pred: 1
#
# Original Text: This movie now joins Revenge of the Boogeyman and Zombiez as part of the hellish trinity of horror films.
# Preprocessed Text: movie joins revenge boogeyman zombiez part hellish trinity horror films
# True: 0, Pred: 1
#
# Original Text: This film has no redeeming features.
# Preprocessed Text: film redeeming features
# True: 0, Pred: 1
#
# Original Text: It's this pandering to the audience that sabotages most of his films.
# Preprocessed Text: pandering audience sabotages films
# True: 0, Pred: 1
#
# Original Text: Every element of this story was so over the top, excessively phony and contrived that it was painful to sit through.
# Preprocessed Text: every element story top excessively phony contrived painful sit
# True: 0, Pred: 1
#
# Original Text: The new characters weren't all that memorable, and I found myself forgetting who was who.
# Preprocessed Text: new characters werent memorable found forgetting
# True: 0, Pred: 1
#
# Original Text: Editing: The editing of this film was phenomenal in my opinion.
# Preprocessed Text: editing editing film phenomenal opinion
# True: 1, Pred: 0
#
# Original Text: BLACK WATER is a thriller that manages to completely transcend it's limitations (it's an indie flick) by continually subverting expectations to emerge as an intense experience.
# Preprocessed Text: black water thriller manages completely transcend limitations indie flick continually subverting expectations emerge intense experience
# True: 1, Pred: 0
#
# Original Text: I won't say any more - I don't like spoilers, so I don't want to be one, but I believe this film is worth your time.
# Preprocessed Text: wont say dont like spoilers dont want one believe film worth time
# True: 1, Pred: 0
#
# Original Text: It's a long time since I was so entertained by a movie.
# Preprocessed Text: long time since entertained movie
# True: 1, Pred: 0
#
# Original Text: I think i was one of the people who found this another one of roth's pearls.
# Preprocessed Text: think one people found another one roths pearls
# True: 1, Pred: 0
#
# Original Text: I'm a big fan of this series mostly due to Anne Rice's style, sensitivities and treatments.
# Preprocessed Text: im big fan series mostly due anne rices style sensitivities treatments
# True: 1, Pred: 0
#
# Original Text: It's the one movie that never ceases to interest me, simply because it keeps me alert, as I try to attempt to decipher it's meanings.
# Preprocessed Text: one movie never ceases interest simply keeps alert try attempt decipher meanings
# True: 1, Pred: 0
#
# Original Text: This movie is excellent!Angel is beautiful and Scamp is adorable!His little yelps when hes scared,and the funniest parts are when:Scamp is caught under the curtain and when Angel and Scamp are singing 'Ive Never Had This Feeling Before'.I totally recommend this movie,its coming out on special edition on June 20.The cover has scamp on a garbage can and Angel underneath the lid.
# Preprocessed Text: movie excellentangel beautiful scamp adorablehis little yelps hes scaredand funniest parts whenscamp caught curtain angel scamp singing ive never feeling beforei totally recommend movieits coming special edition june 20the cover scamp garbage angel underneath lid
# True: 1, Pred: 0
#
# Original Text: Go watch it!
# Preprocessed Text: go watch
# True: 1, Pred: 0
#
# Original Text: I believe that Pitch Black was done well.
# Preprocessed Text: believe pitch black done well
# True: 1, Pred: 0
#
# Original Text: But it picked up speed and got right to the point.
# Preprocessed Text: picked speed got right point
# True: 1, Pred: 0
#
# Original Text: It has everything you could want... suspense, drama, comedy, confusing subplots, native americans, brain eating... If you're looking for the be-all, end-all of brainsucking movies, look no further.
# Preprocessed Text: everything could want suspense drama comedy confusing subplots native americans brain eating youre looking beall endall brainsucking movies look
# True: 1, Pred: 0
#
# Original Text: I keep watching it over and over.
# Preprocessed Text: keep watching
# True: 1, Pred: 0
#
# Original Text: If you want a real scare rent this one!
# Preprocessed Text: want real scare rent one
# True: 1, Pred: 0
#
# Original Text: Later I found myself lost in the power of the film.
# Preprocessed Text: later found lost power film
# True: 1, Pred: 0
#
# Original Text: The film succeeds despite, or perhaps because of, an obviously meagre budget.
# Preprocessed Text: film succeeds despite perhaps obviously meagre budget
# True: 1, Pred: 0
#
# Original Text: Then I watched it again two Sundays ago (March 20th, 2005) and I began to really enjoy it and this time I taped the entire thing.
# Preprocessed Text: watched two sundays ago march 20th 2005 began really enjoy time taped entire thing
# True: 1, Pred: 0
#
# Original Text: Nothing short of magnificent photography/cinematography in this film.
# Preprocessed Text: nothing short magnificent photographycinematography film
# True: 1, Pred: 0
#
# Original Text: The performances are real and gripping, the crocdodile is extremely well done, indeed if the Black Water website is to be believed that's because they used real crocs and the swamp location is fabulous.
# Preprocessed Text: performances real gripping crocdodile extremely well done indeed black water website believed thats used real crocs swamp location fabulous
# True: 1, Pred: 0
#
# Original Text: See it.
# Preprocessed Text: see
# True: 1, Pred: 0
#
# Original Text: Don't be afraid of subtitles........ its worth a little aversion therapy 10/10
# Preprocessed Text: dont afraid subtitles worth little aversion therapy 1010
# True: 1, Pred: 0
#
# Original Text: A standout scene.
# Preprocessed Text: standout scene
# True: 1, Pred: 0
#
# Original Text: My 8/10 score is mostly for the plot.
# Preprocessed Text: 810 score mostly plot
# True: 1, Pred: 0
#
# Original Text: Perabo has a nice energy level and is obviously very comfortable in front of a camera.
# Preprocessed Text: perabo nice energy level obviously comfortable front camera
# True: 1, Pred: 0
#
# Original Text: I work in the hospitality industry in Paradise Valley and have refrained from recommending Cibo any longer.
# Preprocessed Text: work hospitality industry paradise valley refrained recommending cibo longer
# True: 0, Pred: 1
#
# Original Text: I got food poisoning here at the buffet.
# Preprocessed Text: got food poisoning buffet
# True: 0, Pred: 1
#
# Original Text: The only downside is the service.
# Preprocessed Text: downside service
# True: 0, Pred: 1
#
# Original Text: No allergy warnings on the menu, and the waitress had absolutely no clue as to which meals did or did not contain peanuts.
# Preprocessed Text: allergy warnings menu waitress absolutely clue meals contain peanuts
# True: 0, Pred: 1
#
# Original Text: I seriously cannot believe that the owner has so many unexperienced employees that all are running around like chickens with their heads cut off.
# Preprocessed Text: seriously believe owner many unexperienced employees running around like chickens heads cut
# True: 0, Pred: 1
#
# Original Text: What SHOULD have been a hilarious, yummy Christmas Eve dinner to remember was the biggest fail of the entire trip for us.
# Preprocessed Text: hilarious yummy christmas eve dinner remember biggest fail entire trip us
# True: 0, Pred: 1
#
# Original Text: the food is not tasty at all, not to say its "real traditional Hunan style".
# Preprocessed Text: food tasty say real traditional hunan style
# True: 0, Pred: 1
#
# Original Text: And then tragedy struck.
# Preprocessed Text: tragedy struck
# True: 0, Pred: 1
#
# Original Text: And it was way to expensive.
# Preprocessed Text: way expensive
# True: 0, Pred: 1
#
# Original Text: I've had better atmosphere.
# Preprocessed Text: ive better atmosphere
# True: 0, Pred: 1
#
# Original Text: My salad had a bland vinegrette on the baby greens and hearts of Palm.
# Preprocessed Text: salad bland vinegrette baby greens hearts palm
# True: 0, Pred: 1
#
# Original Text: They brought a fresh batch of fries and I was thinking yay something warm but no!
# Preprocessed Text: brought fresh batch fries thinking yay something warm
# True: 0, Pred: 1
#
# Original Text: However, my recent experience at this particular location was not so good.
# Preprocessed Text: however recent experience particular location good
# True: 0, Pred: 1
#
# Original Text: Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best.
# Preprocessed Text: maybe vegetarian fare ive twice thought average best
# True: 0, Pred: 1
#
# Original Text: When I opened the sandwich, I was impressed, but not in a good way.
# Preprocessed Text: opened sandwich impressed good way
# True: 0, Pred: 1
#
# Original Text: This place is not worth your time, let alone Vegas.
# Preprocessed Text: place worth time let alone vegas
# True: 0, Pred: 1
#
# Original Text: The feel of the dining room was more college cooking course than high class dining and the service was slow at best.
# Preprocessed Text: feel dining room college cooking course high class dining service slow best
# True: 0, Pred: 1
#
# Original Text: The desserts were a bit strange.
# Preprocessed Text: desserts bit strange
# True: 0, Pred: 1
#
# Original Text: I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine.
# Preprocessed Text: im really sure joeys voted best hot dog valley readers phoenix magazine
# True: 0, Pred: 1
#
# Original Text: !....THE OWNERS REALLY REALLY need to quit being soooooo cheap let them wrap my freaking sandwich in two papers not one!
# Preprocessed Text: owners really really need quit soooooo cheap let wrap freaking sandwich two papers one
# True: 0, Pred: 1
#
# Original Text: Crust is not good.
# Preprocessed Text: crust good
# True: 0, Pred: 1
#
# Original Text: Also, I feel like the chips are bought, not made in house.
# Preprocessed Text: also feel like chips bought made house
# True: 0, Pred: 1
#
# Original Text: Also there are combos like a burger, fries, and beer for 23 which is a decent deal.
# Preprocessed Text: also combos like burger fries beer 23 decent deal
# True: 1, Pred: 0
#
# Original Text: Their rotating beers on tap is also a highlight of this place.
# Preprocessed Text: rotating beers tap also highlight place
# True: 1, Pred: 0
#
# Original Text: I really do recommend this place, you can go wrong with this donut place!
# Preprocessed Text: really recommend place go wrong donut place
# True: 1, Pred: 0
#
# Original Text: Nice blanket of moz over top but i feel like this was done to cover up the subpar food.
# Preprocessed Text: nice blanket moz top feel like done cover subpar food
# True: 1, Pred: 0
#
# Original Text: Phenomenal food, service and ambiance.
# Preprocessed Text: phenomenal food service ambiance
# True: 1, Pred: 0
#
# Original Text: Nicest Chinese restaurant I've been in a while.
# Preprocessed Text: nicest chinese restaurant ive
# True: 1, Pred: 0
#
# Original Text: The owner used to work at Nobu, so this place is really similar for half the price.
# Preprocessed Text: owner used work nobu place really similar half price
# True: 1, Pred: 0
#
# Original Text: Today was my first taste of a Buldogis Gourmet Hot Dog and I have to tell you it was more than I ever thought possible.
# Preprocessed Text: today first taste buldogis gourmet hot dog tell ever thought possible
# True: 1, Pred: 0
#
# Original Text: It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.
# Preprocessed Text: like really sexy party mouth youre outrageously flirting hottest person party
# True: 1, Pred: 0
#
# Original Text: If you haven't gone here GO NOW!
# Preprocessed Text: havent gone go
# True: 1, Pred: 0
#
# Original Text: One nice thing was that they added gratuity on the bill since our party was larger than 6 or 8, and they didn't expect more tip than that.
# Preprocessed Text: one nice thing added gratuity bill since party larger 6 8 didnt expect tip
# True: 1, Pred: 0
#
# Original Text: I went to Bachi Burger on a friend's recommendation and was not disappointed.
# Preprocessed Text: went bachi burger friends recommendation disappointed
# True: 1, Pred: 0
#
# Original Text: I promise they won't disappoint.
# Preprocessed Text: promise wont disappoint
# True: 1, Pred: 0
#
# Original Text: #NAME?
# Preprocessed Text: name
# True: 1, Pred: 0
#
# Original Text: Will go back next trip out.
# Preprocessed Text: go back next trip
# True: 1, Pred: 0
#
# Original Text: Go To Place for Gyros.
# Preprocessed Text: go place gyros
# True: 1, Pred: 0
#
# Original Text: Seriously killer hot chai latte.
# Preprocessed Text: seriously killer hot chai latte
# True: 1, Pred: 0
#
# Original Text: Extremely Tasty!
# Preprocessed Text: extremely tasty
# True: 1, Pred: 0
#
# Original Text: You can't beat that.
# Preprocessed Text: cant beat
# True: 1, Pred: 0
#
# Original Text: #NAME?
# Preprocessed Text: name
# True: 1, Pred: 0
